# %% [markdown]
# Mediante un programa de python se inscribieron los alumnos de una escuela, sus nombres fueron guardados en la lista alumnos. Contesta las preguntas y realiza las actividades que se piden con la lista.

# %%
escuela=["rincon rodriguez, Ana","Hernández Rodríguez, José", "Hernández Sánchez, José", "Rodríguez Rincón, Isabel","Aguilar López, Juan","Santiago Rodríguez, Roberto","Esquivel Rodríguez, Sofia","Zavala Aguilar, María","Acevedo, María","Juana Sofia, Escobar López"]

# %% [markdown]
# ###Después se descubrieron algunos errores en la lista, corrigelos con los métodos o funciones adecuadas.
# #####Error1: La primera alumna en registrarse "rincon rodriguez, Ana" no puso en mayúsculas la letra inicial de cada apellido, corrigelo. (verifica que se corrija utilizando la función print)

# %%
escuela[0]=escuela[0].title()

# %%
print(escuela) #verifica si funcionó
# Out:
# ['Rincon Rodriguez, Ana', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rodríguez Rincón, Isabel', 'Aguilar López, Juan', 'Santiago Rodríguez, Roberto', 'Esquivel Rodríguez, Sofia', 'Zavala Aguilar, María', 'Acevedo, María', 'Juana Sofia, Escobar López']

# %% [markdown]
# ####Error2: La alumna "Juana Sofia, Escobar López" se equivocó y se registró de esta manera en lugar de poner su apellido primero y después su nombre, cambialo. (Tip, utiliza un método para encontrar primero el índice del nombre con el error y después reemplaza el elemento como vimos la clase anterior)

# %%
escuela.index("Juana Sofia, Escobar López")
# Out:
# 9

# %%
nombre_completo=escuela[9].split(", ")

# %%
nombre_completo_corregido=nombre_completo[1]+" "+nombre_completo[0]

# %%
escuela[9]=nombre_completo_corregido
print(escuela)
# Out:
# ['Rincon Rodriguez, Ana', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rodríguez Rincón, Isabel', 'Aguilar López, Juan', 'Santiago Rodríguez, Roberto', 'Esquivel Rodríguez, Sofia', 'Zavala Aguilar, María', 'Acevedo, María', 'Escobar López Juana Sofia']

# %% [markdown]
# Error 3. La alumna "Acevedo, María" olvidó poner su segundo apellido: García, corrijelo. (Similar al ejercicio anterior)

# %%
escuela.index("Acevedo, María")
# Out:
# 8

# %%
nombre3=escuela[8].split(", ")
nombre_completo_corregido3=nombre3[0]+", "+nombre3[1]+ " García"
escuela[error3]=nombre_completo_corregido3
print(escuela)
# Out:
# ['Rincon Rodriguez, Ana', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rodríguez Rincón, Isabel', 'Aguilar López, Juan', 'Santiago Rodríguez, Roberto', 'Esquivel Rodríguez, Sofia', 'Zavala Aguilar, María', 'Acevedo, María García', 'Escobar López Juana Sofia']

# %% [markdown]
# Error 4. La alumna Zavala Aguilar, María se dio de baja, habrá que eliminarla de la lista

# %%
escuela.remove("Zavala Aguilar, María")
print(escuela)
# Out:
# ['Rincon Rodriguez, Ana', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rodríguez Rincón, Isabel', 'Aguilar López, Juan', 'Santiago Rodríguez, Roberto', 'Esquivel Rodríguez, Sofia', 'Acevedo, María García', 'Escobar López Juana Sofia']

# %% [markdown]
# Error 5. La alumna "García Espinoza, Clara" se dio de alta, agregala a la lista

# %%
escuela.append("García Espinoza, Clara")
print(escuela)
# Out:
# ['Rincon Rodriguez, Ana', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rodríguez Rincón, Isabel', 'Aguilar López, Juan', 'Santiago Rodríguez, Roberto', 'Esquivel Rodríguez, Sofia', 'Acevedo, María García', 'Escobar López Juana Sofia', 'García Espinoza, Clara']

# %% [markdown]
# Finalmente, necesitas la lista ordenada alfabeticamente, ordenala. (Vimos la función para ordenar hoy)

# %%
escuela.sort()

# %%
print(escuela)
# Out:
# ['Acevedo, María García', 'Aguilar López, Juan', 'Escobar López Juana Sofia', 'Esquivel Rodríguez, Sofia', 'García Espinoza, Clara', 'Hernández Rodríguez, José', 'Hernández Sánchez, José', 'Rincon Rodriguez, Ana', 'Rodríguez Rincón, Isabel', 'Santiago Rodríguez, Roberto']
