# %% [markdown]
# #Funciones, metodos y paquetes
# ##Veamos la diferencia entre estos 3 y conozcamos algunos de ellos

# %% [markdown]
# ##Funciones

# %%
#Encuentra el resultado de 2 a la 3 utilizando la función pow

# %%
#lo guardamos en la variable a

# %%
#¿Qué sucede si elevamos a al cuadrado, de nuevo con la función pow?
# Out:
# 64

# %%
help(pow) #Utilicemos la función help para conocer más sobre pow

# %%
#Agregemos un tercer argumento a la función, correspondiente a módulo, para saber cuál es el residuo de dividir 2 a la 5 entre 3

# %%
print(2**5,3*10)
# Out:
# 32 30

# %%
lista=[1,3,7,17,2,65] #Definimos una lista

# %%
help(sorted) # el simbolo/ significa que los argumentos antes de este son posicionales, y el * significa que los argumentos despues son key words
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
#Utilicemos la función sorted para ordenar la lista
# Out:
# [1, 2, 3, 7, 17, 65]

# %%
#Ordenemosla de mayor a menor
# Out:
# [65, 17, 7, 3, 2, 1]

# %%
lista2=["Mexico","aus","AUS","USA","Italy"] #Nueva lista con strings, tiene mayúsculas y minúsculas

# %%
#Utilicemos sorted sobre la lista2 ¿Qué sucede?

# %%
"A"<"a" #python acomoda los elementos de menor a mayor (las mayusculas son menores que las minúsculas)
# Out:
# True

# %%
print(len("AUS")); print(len("aus"))
# Out:
# 3
# 3

# %%
 #Ahora acomodemos los elementos del más corto al más largo

# %%
max(lista2) #función max me da el elemento más grande

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
#Usemos max para que nos diga el elemento más largo en la lista 2

# %%
#Elemento más grande en lista

# %%
#Función min para conocer el elemento más chico en una lista

# %%
round(1.78564545,1) #Función round para redondear

# %% [markdown]
# ##Métodos

# %%
lista2
# Out:
# ['Mexico', 'aus', 'AUS', 'USA', 'Italy']

# %%
lista2.index("Italy")#Encontremos el índice de Italy en la lista2
# Out:
# 4

# %%
lista2.count("aus")#numero de veces que aparece "aus" en la lista
# Out:
# 1

# %%
lista2[3]  #Veamos cuál es el elemento de índice 3 en la lista
# Out:
# 'USA'

# %%
lista2[3].capitalize()#Capitalize nos sirve para cambiar una palabra de manera que solo la letra inicial sea mayúscula, es un método de str
# Out:
# 'Usa'

# %%
pais="italia" #Definimos la variable país
type(pais)
# Out:
# str

# %%
print(pais.capitalize()) #Cambiemos la letra inicial de Italia a mayúscula, veamos si el método capitalize cambia la variable
print(pais)  #print para ver si cambia la variable
# Out:
# Italia
# italia

# %%
print(pais.replace("ia","y"))
print(pais) #Realmente cambia la variable?
# Out:
# italy
# italia

# %%
pais.index("ia") #¿Cuál es el índice de "ia" en la palatra italia?
# Out:
# 4

# %%
print(pais.upper(), pais)#upper cambia todas las letras a mayúscula
 #Verifica si cambió la variable
# Out:
# ITALIA italia

# %%
pais2="AUSTRALIA" #Qué pasa si la palabra ya está en mayúsculas?

# %% [markdown]
# Repasemos los métodos de listas

# %%
lista2
# Out:
# ['Mexico', 'aus', 'AUS', 'USA', 'Italy']

# %%
lista2.append("Canadá")#Agrega Canadá
print(lista2)  #Verifica si cambió la variable
# Out:
# ['Mexico', 'aus', 'AUS', 'USA', 'Italy', 'Canadá']

# %%
del(lista2[1]) #Quitemos "aus"
print(lista2) #Verificamos
# Out:
# ['Mexico', 'AUS', 'USA', 'Italy', 'Canadá']

# %%
lista2.pop(3) #¿Qué hace este método?
print(lista2)
# Out:
# ['Mexico', 'AUS', 'USA']

# %%
help(list) #

# %%
#Qué hace el método de pop?

# %%
help(float)

# %%
v=5.3

# %%
v.is_integer()
# Out:
# False

# %%
int(v)
# Out:
# 5

# %%
abs(v)
print(v)
# Out:
# 5.3

# %%
abs(-3)
# Out:
# 3

# %% [markdown]
# Paquetes y librerías

# %%
import math  #Importamos el paquete math para poderlo usar
math.pi #Usamos la función pi de math
# Out:
# 3.141592653589793

# %%
m.radians(60) #Usamos la función radians para convertir 60 grados a radianes
# Out:
# 1.0471975511965976

# %%
import math as m #Importamos la función math como m
round(m.radians(60),3)
# Out:
# 1.047

# %%
m.floor(1.047)# Lo convieere al entero inferior
# Out:
# 1

# %%
m.ceil(1.99)# Lo convieere al entero superior
# Out:
# 2

# %%
m.pi#Usemos de nuevo pi
#Convirtamos de nuevo grados a radianes
# Out:
# 3.141592653589793

# %%
from math import radians #En esta opción solo importamos radianes del paquete math por lo que ya se puede usar la palabra radians como función de manera directa

# %%
radians(60) #Hagamos la misma conversión de 60 grados a radianes
# Out:
# 1.0471975511965976

# %% [markdown]
# ##Crea tu propia función
# Creemos una función llamada mi_función que me devuelva el valor de una división redondeado a un decimal

# %%
def mi_función(v1,v2):
  a=v1/v2
  return(round(a,1))

# %%
mi_función(12.285,3)
# Out:
# 4.1

# %%
Resultado=mi_función(12.285,3)

# %%
print(Resultado)
# Out:
# 4.1
